# %% [markdown]
# # 高额交际费分析

# %% [raw]
# 流程<br>
# １．把人均交际费金额较高的申请人检索出，做成列表。 <br>
# ２．将列表中前10%的申请人向上司汇报。<br>
#
# 明细数据抽出条件 <br>
# 检索出如下<br>
# -------------------------------------------<br>
# 礼品费<br>
# 礼金<br>
# 国外出差餐饮费<br>
# 小额餐饮费<br>
# 大额餐饮费<br>
# 大额接待费<br>
# 小额接待费

# %% [markdown]
# ## 数据洞察概要

# %% [raw]
# 共检索出1940件数据。其中，70%的申请属于A分公司，而D分公司的申请数目在3%以内。<br>
# 85%的申请在250元以上，2万元以上的申请有5条。

# %% [markdown]
# ## 数据统计

# %%
# The code was removed by DSX for sharing.

# %% [markdown]
# ### 1.按分公司统计

# %%
df_data_1 = pd.read_csv(get_object_storage_file_with_credentials_9e4b9e3cb0c64541a038225e909d5e38('MyPython', 'statics-1.csv'))
df_data_1.head(3)
# Out:
#   ﻿CorpName Category  Value  Percent
# 0      A分公司       人数    714     91.0
# 1      B分公司       人数     46      5.9
# 2      C分公司       人数     24      3.1

# %%
# %brunel data('df_data_1') bar x(Category) y(Percent) color(CorpName) stack label(Percent) style('.label{fill:white;text-shadow:none}') effect(enter:2000)  title("分公司统计")  axes(y:8:grid:"百分比",x:5:"分类"):: width=800, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0f38c55d-ff69-4b0d-af31-bf990ab5b3ef/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0f38c55d-ff69-4b0d-af31-bf990ab5b3ef/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
# ...

# %% [markdown]
# #### 分公司A的人数和申请额占了绝大多数

# %% [markdown]
# ### 2.申请件数和金额范围的比较

# %%
df_data_2 = pd.read_csv(get_object_storage_file_with_credentials_9e4b9e3cb0c64541a038225e909d5e38('MyPython', 'statics-2.csv'))
df_data_2.head(3)
# Out:
#   ﻿PriceCategory  Items    Amount    比例
# 0          <100元     39   ¥24,564  1.5%
# 1           200元    220  ¥322,048  8.4%
# 2           300元    250  ¥601,608  9.5%

# %%
# %brunel data('df_data_2') bar x(PriceCategory) y(Items) color(PriceCategory) label(Items) style('.label{fill:white;text-shadow:none}') sort(PriceCategory) effect(enter:2000)  title("申请件数 vs 金额范围")  axes(y:1200:grid:"件数",x:10:"金额"):: width=800, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0f38c55d-ff69-4b0d-af31-bf990ab5b3ef/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0f38c55d-ff69-4b0d-af31-bf990ab5b3ef/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
# ...

# %% [markdown]
# #### 按申请金额范围来划分，半数以上的申请额 >1000

# %% [markdown]
# ### 3.费用和部门的关系

# %%
df_data_3 = pd.read_csv(get_object_storage_file_with_credentials_9e4b9e3cb0c64541a038225e909d5e38('MyPython', 'sample_nodes.csv'))
df_data_3.head(3)
# Out:
#    ﻿Node Group  Count
# 0  上海分公司    部门     22
# 1     餐饮    费用     23
# 2    公关部    部门     15

# %%
df_data_4 = pd.read_csv(get_object_storage_file_with_credentials_9e4b9e3cb0c64541a038225e909d5e38('MyPython', 'sample_edges.csv'))
df_data_4.head()
# Out:
#    ﻿From   To  Count
# 0  上海分公司   餐饮     12
# 1    公关部  高尔夫     35
# 2    高尔夫  座谈会     24
# 3    公关部   打包     10
# 4  武汉分公司   关系     15

# %%
# %brunel data('df_data_4') edge key(From, To) size(Count)  + data('df_data_3')  network(1.2) key(Node) size(Count) color(Group) label(Node) style("label-location:top") tooltip(Count) title("费用和部门关系图"):: width=800, height=300
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0f38c55d-ff69-4b0d-af31-bf990ab5b3ef/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0f38c55d-ff69-4b0d-af31-bf990ab5b3ef/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
# ...

# %% [markdown]
# #### 上海分公司[餐饮]消费偏多，公关部有很大的[高尔夫]消费，武汉和宁波的[茶叶]消费居多
